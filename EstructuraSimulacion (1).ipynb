# %% [markdown]
# <center><img src=https://www.uv.mx/veracruz/nutricion/files/2012/10/Logo-UV2-229x300.jpg width=150>
# <h1>Programación científica</h1>
# <h2>< Tiro parabólico   ></h2>
# <h2>< Equipo 6  ></h2>
# <h3><i>< Castillo Jiménez Brandon Uziel ></i></h3></center>
# <center>< 24 de julio del 2020 ></center>

# %% [markdown]
# # Introducción
#
#
# 1.   Propósito \\
# El propósito de nuestra simulación es recrear las causas que originan el movimiento de un objeto que a su vez describe una trayectoria parabólica en la que afecta el rozamiento o fricción del aire.
# La idea es hacer uso del programa Python y de las herramientas que el mismo programa proporciona para simular mediante una animación interactiva el tiro parabólico (también llamado tiro balístico).
#
# 2.   A que laboratorio corresponde \\
# Basándonos en las características del experimento/simulación, así como también la rama de que estos conceptos se desprenden. El laboratorio al que pertenecen es al laboratorio de mecánica.

# %% [markdown]
# ## Marco Teórico
#
# 1. Dinámica \\
# Dinámica es la parte de la mecánica que estudia la relación entre el movimiento y las causas que lo producen (las fuerzas). El movimiento de un cuerpo es el resultado de las interacciones con otros cuerpos que se describen mediante fuerzas a su vez esta describe la evolución en el tiempo de un sistema físico.
# El objetivo de la dinámica es describir los factores capaces de producir alteraciones de un sistema físico, cuantificarlos y plantear ecuaciones de movimiento o ecuaciones de evolución para dicho sistema de operación. El estudio de la dinámica es prominente en los sistemas mecánicos; pero también en la termodinámica y electrodinámica.
# La dinámica en el ámbito de la física está regulada por las Leyes de Newton lo cual obedece a 3 leyes: la primera ley, indica que un cuerpo se mantendrá en reposo o movimiento uniforme excepto que sobre el cuerpo actúe una fuerza; la segunda ley, establece que la variación del movimiento de los cuerpos es proporcional a la fuerza que se ejerce sobre él; la tercera ley, expresa que el impulso de una fuerza constante es el producto de la misma por el tiempo que actúa y produce una alteración en la cantidad de movimiento sobre el cuerpo afectado.
#  La evolución en el tiempo de los sistemas dinámicos puede ser descrita por un conjunto finito de ecuaciones diferenciales ordinarias, razón por la cual se dice que tiene un número finito de grados de libertad.
#
# 2. Tiro parabólico con resistencia \\
# Para dar una introducción breve sobre la dinámica implícita en el tiro parabólico, hablemos de algo conocido como tiro balístico o trayectoria balística:
# La trayectoria balística es la trayectoria de vuelo que sigue un proyectil sometido únicamente a su propia inercia y a las fuerzas inherentes al medio en el que se desplaza, principalmente la fuerza gravitatoria.
# La ciencia que estudia los fenómenos balísticos en general se denomina balística. La balística exterior estudia la trayectoria balística bajo diversas condiciones.
# Cuando sobre el proyectil tan solo actúa la gravedad, la trayectoria balística es una parábola. Sin embargo, la presencia de otras fuerzas, tales como la resistencia aerodinámica (atmósfera), la fuerza de sustentación, la fuerza de Coriolis (efecto de la rotación terrestre que consiste en la existencia de una aceleración relativa del cuerpo en dicho sistema en rotación. Esta aceleración es siempre perpendicular al eje de rotación del sistema y a la velocidad del cuerpo.), etc. hace que la trayectoria real sea algo diferente de una parábola. \\
# Para la deducción de las ecuaciones que dan explicación acerca de este movimiento son las siguientes. \\
# ●	El alcance del proyectil es suficientemente pequeño como para poder despreciar la curvatura de la superficie terrestre (la aceleración gravitatoria es normal a dicha superficie); \\
# ●	La altura que alcanza el proyectil es suficientemente pequeña como para poder despreciar la variación del campo gravitatorio terrestre con la altura; \\
# ●	La velocidad del proyectil es suficientemente pequeña como para poder despreciar la resistencia que presenta el aire a su movimiento. \\
# ●	No tendremos en cuenta el efecto de rotación de la Tierra que, como veremos más adelante, tiende a desviar el proyectil hacia la derecha de su trayectoria cuando el movimiento tiene lugar en el hemisferio Norte. \\
# Sin embargo, haremos hincapié en esto únicamente para la deducción de fórmulas que no se vean afectadas por un rozamiento. \\
# Movimiento balístico con fricción o tiro parabólico con fricción:
# Se supone que el efecto del viento sobre el proyectil es el de una fuerza proporcional a la velocidad relativa entre el viento y el proyectil. Sea u la velocidad del viento y α el ángulo que hace la dirección de esta velocidad con el eje X. \\
# Las ecuaciones del movimiento a lo largo del eje X y del eje Y se escriben como:
# Para un proyectil disparado con velocidad v0 y ángulo de tiro θ0. Las componentes de las velocidades iniciales son:

# %% [markdown]
# # Instrucciones de uso de su simulación:

# %% [markdown]
# * Descripción de los controles.
# 1. Control para la velocidad del aire (m/s).
# 2. Control para la dirección del vector velocidad del viento (en grados).
# 3. Control para la velocidad del proyectil (m/s).
# 4. Control para la direccion inicial del proyectil (en grados).
# 5. Control para el foecifiente de fricción.
# 6. Controles parala animacion.animación.

# %% [markdown]
# # Códigos

# %%
# Bibliotecas
import matplotlib.pyplot as plt
from matplotlib import animation, rc
import numpy as np
from ipywidgets import interactive, fixed, interact_manual 
import ipywidgets as widgets 
from IPython.display import display
from scipy.optimize import newton
import math

# %%
# Funciones (ponga cada función en una celda independiente)

#A=0
#B=np.radians(180)
#C=35
#D=np.radians(45)
#F=.01
#H=9.81
def az(A,B,C,D,F):

 def g(T):
  u=A
  p=B
  v=C
  d=D
  b=F
  g=H
  return (1/b)*((g/b)+v*np.sin(d)-u*np.sin(p))*(1-math.e**(-b*T))-((g/b)-u*np.sin(p))*T


 t=newton(g,6)
 j=(A*np.cos(B)*t)+(1/F)*(C*np.cos(D)-A*np.cos(B))*(1-math.e**(-F*t))
 Hmax=(C*np.sin(D))**2/(2*H)


 if(j<Hmax):
  Tamaño=0.05*j
 else:
  Tamaño=0.05*U


 xx=np.linspace(0,t,100)
 x=(A*np.cos(B)*xx)+(1/F)*(C*np.cos(D)-A*np.cos(B))*(1-math.e**(-F*xx))
 y=(1/F)*((H/F)+C*np.sin(D)-A*np.sin(B))*(1-math.e**(-F*xx))-((H/F)-A*np.sin(B))*xx


 fig, axis = plt.subplots()
 plt.close()
 if(x[99]<0):
  axis.set_xlim(1.25*min(x),1.25*max(x))
 else:
  axis.set_xlim(0,1.25*max(x))  
 axis.set_ylim(0,1.25*y[50])
 axis.set_xlabel(r'x (m)', fontsize=10)
 axis.set_ylabel(r'y (m)', fontsize=10)
 axis.spines['left'].set_position('zero')
 axis.spines['bottom'].set_position('zero')
 axis.spines['right'].set_visible(False)
 axis.spines['top'].set_visible(False)
 axis.set_aspect('equal')



 misil = plt.Circle((0,0), Tamaño, fc='r')
 axis.add_patch(misil)



 def lanzamiento(n):
    misil.center=(x[n],y[n])
    axis.add_patch(misil)
    return(misil,)



 anim = animation.FuncAnimation(fig, lanzamiento, frames=100, interval=100,blit=True)
 rc('animation',html='jshtml')

# %%
# Construccion de interfaz de usuario.
A=widgets.FloatSlider( #velocidad del aire
    value=50,
    min=0,
    max=100.0,
    step=1,
    description='(m/s):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
B=widgets.FloatSlider(  #angulo de la velocidad del aire
    value=90,
    min=0,
    max=180.0,
    step=1.0,
    description='(\u03C3_viento):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
C=widgets.FloatSlider(  #velocidad del proyectil
    value=60,
    min=0,
    max=120.0,
    step=1.0,
    description='(m/s):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
D=widgets.FloatSlider(  #angulo del proyectil
    value=45,
    min=0,
    max=90.0,
    step=1.0,
    description='(\u03C3_proyectil):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)
F=widgets.FloatSlider(  #coeficiente de rozamiento
    value=.5,
    min=0,
    max=1.0,
    step=0.1,
    description='(Fricción):',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='.1f',
)

# %%
# Despliegue de los controles y salida.
display(A,B,C,D,F)
out=widgets.interactive_output(az,{'A':A,'B':B,'C':C,'D':D,'F':F})
widgets.HBox([out])

anim
# Out:
# FloatSlider(value=17.0, continuous_update=False, description='(m/s):', readout_format='.1f', step=1.0)
# FloatSlider(value=35.0, continuous_update=False, description='(σ_viento):', max=180.0, readout_format='.1f', s…
# FloatSlider(value=99.0, continuous_update=False, description='(m/s):', max=120.0, readout_format='.1f', step=1…
# FloatSlider(value=45.0, continuous_update=False, description='(σ_proyectil):', max=90.0, readout_format='.1f',…
# FloatSlider(value=0.5, continuous_update=False, description='(Fricción):', max=1.0, readout_format='.1f')
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
# ...

# %% [markdown]
# # Referencias:
#
#
# 1.   https://pythonforundergradengineers.com/unicode-characters-in-python.html
# 2.   https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html
# 3.   https://pythonforundergradengineers.com/unicode-characters-in-python.html
# 4.   http://www.sc.ehu.es/sbweb/fisica3/fluidos/viento/parabolico.html
